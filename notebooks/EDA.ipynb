# %%
import pandas as pd

# %%
## Data Ingestions step
df=pd.read_csv('data/finalTrain.csv')
df.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# ...

# %%
df.shape
# Out:
# (45584, 20)

# %%
df.isnull().sum()
# Out:
# ID                                0
# Delivery_person_ID                0
# Delivery_person_Age            1854
# Delivery_person_Ratings        1908
# Restaurant_latitude               0
# Restaurant_longitude              0
# Delivery_location_latitude        0
# Delivery_location_longitude       0
# Order_Date                        0
# Time_Orderd                    1731
# Time_Order_picked                 0
# Weather_conditions              616
# Road_traffic_density            601
# Vehicle_condition                 0
# Type_of_order                     0
# Type_of_vehicle                   0
# multiple_deliveries             993
# Festival                        228
# City                           1200
# Time_taken (min)                  0
# dtype: int64

# %%
df.dtypes
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weather_conditions              object
# Road_traffic_density            object
# Vehicle_condition                int64
# Type_of_order                   object
# Type_of_vehicle                 object
# multiple_deliveries            float64
# Festival                        object
# City                            object
# Time_taken (min)                 int64
# dtype: object

# %%
df1=df

# %%
df1['Delivery_person_Age'].fillna(df1['Delivery_person_Age'].median(),inplace=True)

# %%
df1['Delivery_person_Ratings'].fillna(df1['Delivery_person_Ratings'].median(),inplace=True)

# %%
df1['Time_Orderd'].fillna(df1['Time_Orderd'].mode()[0],inplace=True)

# %%
df1['Weather_conditions'].fillna(df1['Weather_conditions'].mode()[0],inplace=True)

# %%
df1['Road_traffic_density'].fillna(df1['Road_traffic_density'].mode()[0],inplace=True)

# %%
df1['multiple_deliveries'].fillna(df1['multiple_deliveries'].median(),inplace=True)

# %%
df1['Festival'].fillna(df1['Festival'].mode()[0],inplace=True)

# %%
df1['City'].fillna(df1['City'].mode()[0],inplace=True)

# %%
df1.isnull().sum()
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weather_conditions             0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# Time_taken (min)               0
# dtype: int64

# %%
### No missing values present in the data

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45584 entries, 0 to 45583
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           45584 non-null  object
#  1   Delivery_person_ID           45584 non-null  object
#  2   Delivery_person_Age          45584 non-null  float64
#  3   Delivery_person_Ratings      45584 non-null  float64
#  4   Restaurant_latitude          45584 non-null  float64
#  5   Restaurant_longitude         45584 non-null  float64
#  6   Delivery_location_latitude   45584 non-null  float64
#  7   Delivery_location_longitude  45584 non-null  float64
#  8   Order_Date                   45584 non-null  object
#  9   Time_Orderd                  45584 non-null  object
#  10  Time_Order_picked            45584 non-null  object
#  11  Weather_conditions           45584 non-null  object
# ...

# %%
df1.head()
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0  0xcdcd      DEHRES17DEL01                 36.0                      4.2  \
# 1  0xd987      KOCRES16DEL01                 21.0                      4.7
# 2  0x2784     PUNERES13DEL03                 23.0                      4.7
# 3  0xc8b6     LUDHRES15DEL02                 34.0                      4.3
# 4  0xdb64      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# ...

# %%
## Lets drop the id column
df1=df1.drop(labels=['ID'],axis=1)
df1.head()
# Out:
#   Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0      DEHRES17DEL01                 36.0                      4.2  \
# 1      KOCRES16DEL01                 21.0                      4.7
# 2     PUNERES13DEL03                 23.0                      4.7
# 3     LUDHRES15DEL02                 34.0                      4.3
# 4      KNPRES14DEL02                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked
# ...

# %%
## check for duplicated records
df1.duplicated().sum()
# Out:
# 0

# %%
## segregate numerical and categorical columns

numerical_columns=df1.columns[df1.dtypes!='object']
categorical_columns=df1.columns[df1.dtypes=='object']
print("Numerical columns:",numerical_columns)
print('Categorical Columns:',categorical_columns)
# Out:
# Numerical columns: Index(['Delivery_person_Age', 'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Vehicle_condition',
#        'multiple_deliveries', 'Time_taken (min)'],
#       dtype='object')
# Categorical Columns: Index(['Delivery_person_ID', 'Order_Date', 'Time_Orderd', 'Time_Order_picked',
#        'Weather_conditions', 'Road_traffic_density', 'Type_of_order',
#        'Type_of_vehicle', 'Festival', 'City'],
#       dtype='object')

# %%
df1[categorical_columns].describe()
# Out:
#        Delivery_person_ID  Order_Date Time_Orderd Time_Order_picked
# count               45584       45584       45584             45584  \
# unique               1320          44         176               193
# top         JAPRES11DEL02  15-03-2022       21:55             21:30
# freq                   67        1192        2192               495
#
#        Weather_conditions Road_traffic_density Type_of_order Type_of_vehicle
# count               45584                45584         45584           45584  \
# unique                  6                    4             4               4
# top                   Fog                  Low         Snack      motorcycle
# freq                 8269                16077         11530           26429
#
#        Festival           City
# count     45584          45584
# unique        2              3
# top          No  Metropolitian
# freq      44688          35287

# %%
df1['Delivery_person_ID'].value_counts()
# Out:
# Delivery_person_ID
# JAPRES11DEL02     67
# PUNERES01DEL01    67
# VADRES11DEL02     66
# VADRES08DEL02     66
# JAPRES03DEL01     66
#                   ..
# GOARES01DEL03      7
# DEHRES18DEL03      7
# KOCRES16DEL03      6
# KOLRES09DEL03      6
# BHPRES010DEL03     5
# Name: count, Length: 1320, dtype: int64

# %%
df1['Order_Date'].value_counts()
# Out:
# Order_Date
# 15-03-2022    1192
# 03-04-2022    1178
# 13-03-2022    1169
# 26-03-2022    1165
# 24-03-2022    1162
# 09-03-2022    1159
# 05-04-2022    1156
# 05-03-2022    1154
# 07-03-2022    1153
# 03-03-2022    1150
# 21-03-2022    1149
# 11-03-2022    1148
# 19-03-2022    1148
# 30-03-2022    1141
# 01-03-2022    1140
# 28-03-2022    1139
# 17-03-2022    1134
# 01-04-2022    1133
# 02-03-2022    1012
# 10-03-2022     996
# 16-03-2022     995
# 20-03-2022     993
# 02-04-2022     992
# 06-03-2022     986
# 04-03-2022     980
# 29-03-2022     977
# 25-03-2022     974
# 14-03-2022     973
# 11-02-2022     970
# 18-03-2022     968
# 31-03-2022     967
# 27-03-2022     965
# 08-03-2022     964
# 12-03-2022     964
# 23-03-2022     964
# 06-04-2022     961
# 13-02-2022     957
# 15-02-2022     945
# 04-04-2022     941
# 17-02-2022     939
# 12-02-2022     864
# 16-02-2022     861
# 18-02-2022     855
# 14-02-2022     851
# Name: count, dtype: int64

# %%
df1['Time_Orderd'].value_counts()
# Out:
# Time_Orderd
# 21:55          2192
# 17:55           456
# 0.833333333     449
# 22:20           448
# 21:35           446
#                ...
# 14:30            57
# 14:15            56
# 0.666666667      53
# 13:20            52
# 16:30            51
# Name: count, Length: 176, dtype: int64

# %%
df1['Time_Order_picked'].value_counts()
# Out:
# Time_Order_picked
# 21:30    495
# 22:50    474
# 22:40    458
# 18:40    457
# 17:55    456
#         ...
# 08:15     48
# 16:15     46
# 16:10     43
# 17:10     39
# 16:20     38
# Name: count, Length: 193, dtype: int64

# %%
df1['Weather_conditions'].value_counts()
# Out:
# Weather_conditions
# Fog           8269
# Stormy        7584
# Cloudy        7533
# Sandstorms    7494
# Windy         7422
# Sunny         7282
# Name: count, dtype: int64

# %%
df1['Road_traffic_density'].value_counts()
# Out:
# Road_traffic_density
# Low       16077
# Jam       14139
# Medium    10945
# High       4423
# Name: count, dtype: int64

# %%
df1['Type_of_order'].value_counts()
# Out:
# Type_of_order
# Snack     11530
# Meal      11456
# Drinks    11321
# Buffet    11277
# Name: count, dtype: int64

# %%
df1['Type_of_vehicle'].value_counts()
# Out:
# Type_of_vehicle
# motorcycle          26429
# scooter             15273
# electric_scooter     3814
# bicycle                68
# Name: count, dtype: int64

# %%
df1['Festival'].value_counts()
# Out:
# Festival
# No     44688
# Yes      896
# Name: count, dtype: int64

# %%
df1['City'].value_counts()
# Out:
# City
# Metropolitian    35287
# Urban            10133
# Semi-Urban         164
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in numerical_columns:
    sns.histplot(data=df1,x=i,kde=True)
    print('\n')
    plt.show()

# %%
## For categorical data

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in categorical_columns:
    sns.countplot(data=df1,x=i)
    print('\n')
    plt.show()

# %%
## correlation
sns.heatmap(df1[numerical_columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
df1['Delivery_person_ID'].unique()
# Out:
# array(['DEHRES17DEL01', 'KOCRES16DEL01', 'PUNERES13DEL03', ...,
#        'KOCRES04DEL01', 'BHPRES06DEL03', 'GOARES03DEL03'], dtype=object)

# %%
df1.Delivery_person_ID.value_counts().to_dict
# Out:
# <bound method Series.to_dict of Delivery_person_ID
# JAPRES11DEL02     67
# PUNERES01DEL01    67
# VADRES11DEL02     66
# VADRES08DEL02     66
# JAPRES03DEL01     66
#                   ..
# GOARES01DEL03      7
# DEHRES18DEL03      7
# KOCRES16DEL03      6
# KOLRES09DEL03      6
# BHPRES010DEL03     5
# Name: count, Length: 1320, dtype: int64>

# %%
df1_frequency_map=df1.Delivery_person_ID.value_counts().to_dict()

# %%
df1.Delivery_person_ID=df1.Delivery_person_ID.map(df1_frequency_map)

# %%
df1['Order_Date'].unique()
# Out:
# array(['12-02-2022', '13-02-2022', '04-03-2022', '14-02-2022',
#        '02-04-2022', '01-03-2022', '16-03-2022', '20-03-2022',
#        '15-02-2022', '10-03-2022', '11-03-2022', '27-03-2022',
#        '26-03-2022', '05-04-2022', '12-03-2022', '01-04-2022',
#        '05-03-2022', '11-02-2022', '08-03-2022', '03-04-2022',
#        '30-03-2022', '28-03-2022', '18-03-2022', '14-03-2022',
#        '06-04-2022', '04-04-2022', '24-03-2022', '19-03-2022',
#        '09-03-2022', '25-03-2022', '02-03-2022', '13-03-2022',
#        '29-03-2022', '31-03-2022', '17-03-2022', '07-03-2022',
#        '15-03-2022', '16-02-2022', '03-03-2022', '18-02-2022',
#        '23-03-2022', '17-02-2022', '06-03-2022', '21-03-2022'],
#       dtype=object)

# %%
df1.Order_Date.value_counts().to_dict
# Out:
# <bound method Series.to_dict of Order_Date
# 15-03-2022    1192
# 03-04-2022    1178
# 13-03-2022    1169
# 26-03-2022    1165
# 24-03-2022    1162
# 09-03-2022    1159
# 05-04-2022    1156
# 05-03-2022    1154
# 07-03-2022    1153
# 03-03-2022    1150
# 21-03-2022    1149
# 11-03-2022    1148
# 19-03-2022    1148
# 30-03-2022    1141
# 01-03-2022    1140
# 28-03-2022    1139
# 17-03-2022    1134
# 01-04-2022    1133
# 02-03-2022    1012
# 10-03-2022     996
# 16-03-2022     995
# 20-03-2022     993
# 02-04-2022     992
# 06-03-2022     986
# 04-03-2022     980
# 29-03-2022     977
# 25-03-2022     974
# 14-03-2022     973
# 11-02-2022     970
# 18-03-2022     968
# 31-03-2022     967
# 27-03-2022     965
# 08-03-2022     964
# 12-03-2022     964
# 23-03-2022     964
# 06-04-2022     961
# 13-02-2022     957
# 15-02-2022     945
# 04-04-2022     941
# 17-02-2022     939
# 12-02-2022     864
# 16-02-2022     861
# 18-02-2022     855
# 14-02-2022     851
# Name: count, dtype: int64>

# %%
df1_frequency_map=df1.Order_Date.value_counts().to_dict()

# %%
df1.Order_Date=df1.Order_Date.map(df1_frequency_map)

# %%
df1['Time_Orderd'].unique()
# Out:
# array(['21:55', '14:55', '17:30', '09:20', '19:50', '20:25', '20:30',
#        '20:40', '21:15', '20:20', '22:30', '08:15', '19:30', '12:25',
#        '18:35', '20:35', '23:20', '21:20', '23:35', '22:35', '23:25',
#        '13:35', '21:35', '18:55', '14:15', '0.458333333', '09:45',
#        '08:40', '0.958333333', '17:25', '19:45', '19:10', '10:55',
#        '21:40', '0.791666667', '16:45', '11:30', '15:10', '22:45',
#        '22:10', '20:45', '22:50', '17:55', '09:25', '20:15', '22:25',
#        '22:40', '23:50', '15:25', '10:20', '20:55', '10:40', '15:55',
#        '20:10', '12:10', '15:30', '10:35', '21:10', '20:50', '12:35',
#        '0.875', '23:40', '18:15', '18:20', '11:45', '12:45', '23:30',
#        '10:50', '21:25', '10:10', '17:50', '22:20', '12:40', '23:55',
#        '10:25', '08:45', '23:45', '19:55', '22:15', '23:10', '09:15',
#        '18:25', '18:45', '16:50', '1', '14:20', '10:15', '08:50', '0.375',
# ...

# %%
df1.Time_Orderd.value_counts().to_dict
# Out:
# <bound method Series.to_dict of Time_Orderd
# 21:55          2192
# 17:55           456
# 0.833333333     449
# 22:20           448
# 21:35           446
#                ...
# 14:30            57
# 14:15            56
# 0.666666667      53
# 13:20            52
# 16:30            51
# Name: count, Length: 176, dtype: int64>

# %%
df1_frequency_map=df1.Time_Orderd.value_counts().to_dict()

# %%
df1.Time_Orderd=df1.Time_Orderd.map(df1_frequency_map)

# %%
df1['Time_Order_picked'].unique()
# Out:
# array(['22:10', '15:05', '17:40', '09:30', '20:05', '20:35', '15:10',
#        '20:40', '20:50', '21:30', '20:25', '22:45', '08:30', '19:45',
#        '12:30', '18:50', '23:30', '21:35', '23:45', '22:50', '22:40',
#        '23:35', '13:40', '21:45', '19:10', '14:25', '11:10', '09:55',
#        '08:55', '23:10', '17:30', '18:35', '19:50', '19:25',
#        '0.458333333', '19:15', '16:55', '11:40', '15:15', '22:55',
#        '22:25', '20:55', '23:05', '0.75', '0.958333333', '09:40', '20:20',
#        '22:35', '0.916666667', '23:55', '15:40', '10:30', '0.875',
#        '10:50', '16:05', '20:15', '12:15', '15:45', '22:15', '10:45',
#        '15:30', '24:05:00', '21:25', '12:45', '21:15', '18:20', '18:25',
#        '11:50', '12:50', '10:55', '21:40', '10:20', '17:55', '23:50',
#        '12:55', '24:10:00', '10:40', '0.375', '20:45', '0.833333333',
#        '23:15', '22:20', '21:05', '0.708333333', '24:15:00', '21:20',
# ...

# %%
df1.Time_Order_picked.value_counts().to_dict
# Out:
# <bound method Series.to_dict of Time_Order_picked
# 21:30    495
# 22:50    474
# 22:40    458
# 18:40    457
# 17:55    456
#         ...
# 08:15     48
# 16:15     46
# 16:10     43
# 17:10     39
# 16:20     38
# Name: count, Length: 193, dtype: int64>

# %%
df1_frequency_map=df1.Time_Order_picked.value_counts().to_dict()

# %%
df1.Time_Order_picked=df1.Time_Order_picked.map(df1_frequency_map)

# %%
df1['Weather_conditions'].unique()
# Out:
# array(['Fog', 'Stormy', 'Sandstorms', 'Windy', 'Cloudy', 'Sunny'],
#       dtype=object)

# %%
Weather_conditions_map={"Sunny":1,"Cloudy":2,"Windy":3,"Stormy":4,"Fog":5,"Sandstorms":6}

# %%
df1['Road_traffic_density'].unique()
# Out:
# array(['Jam', 'High', 'Medium', 'Low'], dtype=object)

# %%
Road_traffic_density_map={"Low":1,"Medium":2,"High":3,"Jam":4}

# %%
df1['Type_of_order'].unique()
# Out:
# array(['Snack', 'Meal', 'Drinks', 'Buffet'], dtype=object)

# %%
Type_of_order_map={"Drinks":1,"Snack":2,"Meal":3,"Buffet":4}

# %%
df1['Type_of_vehicle'].unique()
# Out:
# array(['motorcycle', 'scooter', 'electric_scooter', 'bicycle'],
#       dtype=object)

# %%
Type_of_vehicle_map={"bicycle":1,"electric_scooter":2,"scooter":3,"motorcycle":4}

# %%
df1['Festival'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
Festival_map={"No":1,"Yes":2}

# %%
df1['City'].unique()
# Out:
# array(['Metropolitian', 'Urban', 'Semi-Urban'], dtype=object)

# %%
City_map={"Semi-Urban":1,"Urban":2,"Metropolitian":3}

# %%
df1['Weather_conditions']=df1['Weather_conditions'].map(Weather_conditions_map)
df1['Road_traffic_density'] = df1['Road_traffic_density'].map(Road_traffic_density_map)
df1['Type_of_order'] = df1['Type_of_order'].map(Type_of_order_map)
df1['Type_of_vehicle']=df1['Type_of_vehicle'].map(Type_of_vehicle_map)
df1['Festival']=df1['Festival'].map(Festival_map)
df1['City']=df1['City'].map(City_map)

# %%
df1.head()
# Out:
#    Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings
# 0                  12                 36.0                      4.2  \
# 1                  13                 21.0                      4.7
# 2                  39                 23.0                      4.7
# 3                  15                 34.0                      4.3
# 4                  13                 24.0                      4.7
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude
# 0            30.327968             78.046106                   30.397968  \
# 1            10.003064             76.307589                   10.043064
# 2            18.562450             73.916619                   18.652450
# 3            30.899584             75.809346                   30.919584
# 4            26.463504             80.372929                   26.593504
#
#    Delivery_location_longitude  Order_Date  Time_Orderd  Time_Order_picked
# ...
